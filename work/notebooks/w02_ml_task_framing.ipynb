# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/komalmakar513/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
task = """
ML Task Type: Ranking

This problem is best framed as a ranking task because the goal is to rank content pages based on their need for content refresh. Instead of predicting only yes or no, the model should prioritize which pages should be refreshed first based on their performance signals.
"""

print(task)
# Out:
# ML Task Type: Ranking
#
# This problem is best framed as a ranking task because the goal is to rank content pages based on their need for content refresh. Instead of predicting only yes or no, the model should prioritize which pages should be refreshed first based on their performance signals.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
target = """
Target: Refresh Priority Score

The model will predict a refresh priority score for each content page. Pages with lower search performance, declining clicks, or outdated content will receive a higher priority score. This target is created from observed website performance data rather than a manually assigned label.
"""

print(target)
# Out:
# Target: Refresh Priority Score
#
# The model will predict a refresh priority score for each content page. Pages with lower search performance, declining clicks, or outdated content will receive a higher priority score. This target is created from observed website performance data rather than a manually assigned label.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# Display dataset information
print("Shape of dataset:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
print(df.head())

# -----------------------------
# Unit of analysis
# -----------------------------

unit = """
Unit of analysis:

Each row represents one webpage (content page).

Each webpage has information such as:
- Clicks
- Impressions
- CTR (Click Through Rate)
- Average Position
- Other search performance metrics

The ML model analyzes each webpage individually to decide
whether it should be refreshed first to improve search performance.
"""

print(unit)
# Out:
# Shape of dataset: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# First 5 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# Show the first 5 rows
print(df.head())

unit = """
Unit of analysis:

Each row represents one webpage (content page).

The columns contain search performance information such as:
- Clicks
- Impressions
- CTR (Click Through Rate)
- Average Position

The ML model analyzes each webpage separately to determine
whether it should be refreshed to improve search performance.
"""

print(unit)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
reason = """
Why ML beats a fixed rule:

A fixed rule cannot capture the complex relationship between
multiple search performance metrics such as clicks, impressions,
CTR, and average position.

Machine learning can learn patterns from historical data and
identify which pages are most likely to benefit from a content
refresh, resulting in better decisions than using simple
if-else rules.
"""

print(reason)
# Out:
# Why ML beats a fixed rule:
#
# A fixed rule cannot capture the complex relationship between
# multiple search performance metrics such as clicks, impressions,
# CTR, and average position.
#
# Machine learning can learn patterns from historical data and
# identify which pages are most likely to benefit from a content
# refresh, resulting in better decisions than using simple
# if-else rules.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
