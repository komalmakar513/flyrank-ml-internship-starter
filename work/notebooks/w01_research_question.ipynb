# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/komalmakar513/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
lane = """
Content Refresh & Search Performance

I chose this lane because search performance changes over time as content becomes older. My goal is to identify which pages should be refreshed first to improve clicks and visibility. Refreshing the right pages can increase traffic without creating entirely new content, making this a practical and valuable business decision.
"""

print(lane)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
question = """
Decision:
Decide which content pages should be refreshed first.

Action:
The SEO/content team will update and optimize those pages.

Cost of a wrong recommendation:
If the wrong pages are selected, time and effort will be wasted while important pages continue losing clicks and traffic.
"""

print(question)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total rows:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Position:", round(df["avg_position"].mean(), 2))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
claims = """
What I can claim:
- I can identify patterns and relationships in the data.
- I can provide recommendations about which pages may benefit from content refresh.
- My analysis supports decision-making using observed data.

What I cannot claim:
- I cannot prove that refreshing content will definitely increase rankings.
- I cannot predict Google's algorithm.
- I cannot claim a direct cause-and-effect relationship from this analysis alone.
"""

print(claims)
# Out:
# What I can claim:
# - I can identify patterns and relationships in the data.
# - I can provide recommendations about which pages may benefit from content refresh.
# - My analysis supports decision-making using observed data.
#
# What I cannot claim:
# - I cannot prove that refreshing content will definitely increase rankings.
# - I cannot predict Google's algorithm.
# - I cannot claim a direct cause-and-effect relationship from this analysis alone.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
